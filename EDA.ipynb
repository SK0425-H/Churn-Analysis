# %% [markdown]
# <a href="https://colab.research.google.com/github/SK0425-H/Churn-Analysis/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
telco_df=pd.read_csv('/content/Customer-Churn.csv')

# %%
telco_df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
telco_df.shape
# Out:
# (7043, 21)

# %%
telco_df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
telco_df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
telco_df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
telco_df.Churn.value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
telco_df.Churn.value_counts()/len(telco_df)*100
# Out:
# No     73.463013
# Yes    26.536987
# Name: Churn, dtype: float64

# %%
missing = pd.DataFrame((telco_df.isnull().sum())*100/telco_df.shape[0]).reset_index()
plt.figure(figsize=(8,3))
ax = sns.pointplot(x='index', y=0,data=missing)
plt.xticks(rotation =90,fontsize =7)
plt.title("Percentage of Missing values")
plt.ylabel("PERCENTAGE")
plt.show()

# %%
telco_df['TotalCharges'] = pd.to_numeric(telco_df['TotalCharges'], errors='coerce')

# %%
telco_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
missing = pd.DataFrame((telco_df.isnull().sum())*100/telco_df.shape[0]).reset_index()
plt.figure(figsize=(8,3))
ax = sns.pointplot(x='index', y=0,data=missing)
plt.xticks(rotation =90,fontsize =7)
plt.title("Percentage of Missing values")
plt.ylabel("PERCENTAGE")
plt.show()

# %%
telco_df['TotalCharges'].mean()
# Out:
# 2283.3004408418656

# %%
telco_df_new=telco_df

# %%
telco_df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
telco_df_new['TotalCharges'].mean()
# Out:
# 2283.3004408418656

# %%
telco_df_new['TotalCharges']=telco_df_new['TotalCharges'].fillna(telco_df_new['TotalCharges'].mean())

# %%
telco_df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
telco_df.dropna(how='any',axis=0,inplace=True)

# %%
telco_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
telco_df.tenure.value_counts()
# Out:
# 1     613
# 72    362
# 2     238
# 3     200
# 4     176
#      ...
# 28     57
# 39     56
# 44     51
# 36     50
# 0      11
# Name: tenure, Length: 73, dtype: int64

# %%
plt.bar(telco_df.tenure.value_counts().index, telco_df.tenure.value_counts().values)
plt.xlabel('Tenure')
plt.ylabel('Frequency')
plt.title('Tenure Distribution')
plt.show()

# %%
print(telco_df.tenure.max())
# Out:
# 72

# %%
labels = ["{0} - {1}".format(i, i+11) for i in range(1,72,12)]
telco_df['tenure_group'] = pd.cut(telco_df.tenure, range(1,80,12), right=False, labels = labels)

# %%
telco_df['tenure_group'].value_counts()
# Out:
# 1 - 12     2175
# 61 - 72    1407
# 13 - 24    1024
# 25 - 36     832
# 49 - 60     832
# 37 - 48     762
# Name: tenure_group, dtype: int64

# %%
telco_df['tenure_group'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
telco_df.drop(columns=['customerID','tenure'],axis=1,inplace=True)

# %%
telco_df.head()
# Out:
#    gender  SeniorCitizen Partner Dependents PhoneService     MultipleLines  \
# 0  Female              0     Yes         No           No  No phone service
# 1    Male              0      No         No          Yes                No
# 2    Male              0      No         No          Yes                No
# 3    Male              0      No         No           No  No phone service
# 4  Female              0      No         No          Yes                No
#
#   InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0             DSL             No          Yes               No          No
# 1             DSL            Yes           No              Yes          No
# 2             DSL            Yes          Yes               No          No
# 3             DSL            Yes           No              Yes         Yes
# 4     Fiber optic             No           No               No          No
#
# ...

# %%
for i, predictor in enumerate(telco_df.drop(columns=['Churn', 'MonthlyCharges', 'TotalCharges'])):
  plt.figure(i)
  sns.countplot(telco_df, x=predictor, hue='Churn') #Churn is the legend
  # Add labels to the bars
  ax = plt.gca()
  for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2, p.get_height()), ha='center', va='bottom')
  plt.xticks(rotation=90)

# %% [markdown]
# Univariate Analysis for Categorical Data **INSIGHTS **
#
# 1. Month tp Month customers are more likely to churn.
# 2. Senior Citizens are more likely to churn.
# 3. Customers without dependents exhibit a lower churn rate.
# 4.Customers who do not engage in streaming movies are more likely to experience high churn.
# 5.Customers who do not utilize streaming TV services are more prone to experiencing high churn.
# 6.Customers without access to tech support are more likely to be associated with high churn.
# 7. Customers without device protection are more likely to experience high churn.
# 8. Customers with a tenure of 1-12 months are characterized by a high churn rate.
# 9. Customers who opt for paperless billing tend to have a higher churn rate.
# 10. Customers utilizing phone services exhibit a high churn rate.

# %%
telco_df['Churn'] = telco_df['Churn'].replace({'Yes': 1, 'No': 0})

# %%
telco_df_Churned = telco_df.loc[telco_df.Churn==1]
telco_df_Active = telco_df.loc[telco_df.Churn==0]

# %%
len(telco_df_Churned)
# Out:
# 1869

# %%
len(telco_df_Active)
# Out:
# 5174

# %%
def uniplot(df,col,title,hue =None):

    sns.set_style('whitegrid')
    sns.set_context('talk')
    plt.rcParams["axes.labelsize"] = 20
    plt.rcParams['axes.titlesize'] = 22
    plt.rcParams['axes.titlepad'] = 30


    temp = pd.Series(data = hue)
    fig, ax = plt.subplots()
    width = len(df[col].unique()) + 7 + 4*len(temp.unique())
    fig.set_size_inches(width , 8)
    plt.xticks(rotation=45)
    plt.yscale('log')
    plt.title(title)
    ax = sns.countplot(data = df, x= col, order=df[col].value_counts().index,hue = hue,palette='bright')

    plt.show()

# %%
plot = sns.catplot(x='Partner', kind='count', data=telco_df_Churned, hue='gender')

# Adding labels
plt.title('Partner vs Gender for Churned Customers')
plt.xlabel('Partner')
plt.ylabel('Count')

# Adding values on top of the bars
ax = plot.facet_axis(0, 0)
for p in ax.patches:
    ax.text(p.get_x() + p.get_width() / 2., p.get_height(), f'{int(p.get_height())}', ha='center', va='bottom')

# Show the plot
plt.show()

# %%
plot = sns.catplot(x='Partner', kind='count', data=telco_df_Active, hue='gender')

# Adding labels
plt.title('Partner vs Gender for Active Customers')
plt.xlabel('Partner')
plt.ylabel('Count')

# Adding values on top of the bars
ax = plot.facet_axis(0, 0)
for p in ax.patches:
    ax.text(p.get_x() + p.get_width() / 2., p.get_height(), f'{int(p.get_height())}', ha='center', va='bottom')

# Show the plot
plt.show()

# %%
plot = sns.catplot(x='SeniorCitizen', kind='count', data=telco_df_Churned, hue='gender')

# Adding labels
plt.title('SeniorCitizen vs Gender for Churned Customers')
plt.xlabel('Partner')
plt.ylabel('Count')

# Adding values on top of the bars
ax = plot.facet_axis(0, 0)
for p in ax.patches:
    ax.text(p.get_x() + p.get_width() / 2., p.get_height(), f'{int(p.get_height())}', ha='center', va='bottom')

# Show the plot
plt.show()

# %%
uniplot(telco_df_Churned,col='SeniorCitizen',title='SC vs Gender for Churned Customers', hue='gender')

# %%
plot = sns.catplot(x='SeniorCitizen', kind='count', data=telco_df_Active, hue='gender')

# Adding labels
plt.title('SC vs Gender for Churned Customers')
plt.xlabel('Partner')
plt.ylabel('Count')

# Adding values on top of the bars
ax = plot.facet_axis(0, 0)
for p in ax.patches:
    ax.text(p.get_x() + p.get_width() / 2., p.get_height(), f'{int(p.get_height())}', ha='center', va='bottom')

# Show the plot
plt.show()

# %%
plot = sns.catplot(x='Dependents', kind='count', data=telco_df_Churned, hue='gender')

# Adding labels
plt.title('Dependent vs Gender for Churned Customers')
plt.xlabel('Dependent')
plt.ylabel('Count')

# Adding values on top of the bars
ax = plot.facet_axis(0, 0)
for p in ax.patches:
    ax.text(p.get_x() + p.get_width() / 2., p.get_height(), f'{int(p.get_height())}', ha='center', va='bottom')

# Show the plot
plt.show()

# %%
plot = sns.catplot(x='Dependents', kind='count', data=telco_df_Active, hue='gender')

# Adding labels
plt.title('Dependent vs Gender for Active Customers')
plt.xlabel('Dependent')
plt.ylabel('Count')

# Adding values on top of the bars
ax = plot.facet_axis(0, 0)
for p in ax.patches:
    ax.text(p.get_x() + p.get_width() / 2., p.get_height(), f'{int(p.get_height())}', ha='center', va='bottom')

# Show the plot
plt.show()

# %%
plot = sns.catplot(x='SeniorCitizen', kind='count', data=telco_df_Active, hue='gender')

# Adding labels
plt.title('SeniorCitizen vs Gender for Active Customers')
plt.xlabel('Partner')
plt.ylabel('Count')

# Adding values on top of the bars
ax = plot.facet_axis(0, 0)
for p in ax.patches:
    ax.text(p.get_x() + p.get_width() / 2., p.get_height(), f'{int(p.get_height())}', ha='center', va='bottom')

# Show the plot
plt.show()

# %%
uniplot(telco_df_Active,col='SeniorCitizen',title='SC vs Gender for Active Customers', hue='gender')

# %%
uniplot(telco_df_Churned,col='PaymentMethod',title='PaymentMethod vs Gender for Churned Customers', hue='gender')

# %%
uniplot(telco_df_Active,col='PaymentMethod',title='PaymentMethod vs Gender for Active Customers', hue='gender')

# %% [markdown]
# Numerical Analysis

# %%
telco_df.head(5)
# Out:
#    gender  SeniorCitizen Partner Dependents PhoneService     MultipleLines  \
# 0  Female              0     Yes         No           No  No phone service
# 1    Male              0      No         No          Yes                No
# 2    Male              0      No         No          Yes                No
# 3    Male              0      No         No           No  No phone service
# 4  Female              0      No         No          Yes                No
#
#   InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0             DSL             No          Yes               No          No
# 1             DSL            Yes           No              Yes          No
# 2             DSL            Yes          Yes               No          No
# 3             DSL            Yes           No              Yes         Yes
# 4     Fiber optic             No           No               No          No
#
# ...

# %%
telco_df_dummies = pd.get_dummies(telco_df)

telco_df_dummies.head(5)
# Out:
#    SeniorCitizen  MonthlyCharges  TotalCharges  Churn  gender_Female  \
# 0              0           29.85         29.85      0              1
# 1              0           56.95       1889.50      0              0
# 2              0           53.85        108.15      1              0
# 3              0           42.30       1840.75      0              0
# 4              0           70.70        151.65      1              1
#
#    gender_Male  Partner_No  Partner_Yes  Dependents_No  Dependents_Yes  ...  \
# 0            0           0            1              1               0  ...
# 1            1           1            0              1               0  ...
# 2            1           1            0              1               0  ...
# 3            1           1            0              1               0  ...
# 4            0           1            0              1               0  ...
#
#    PaymentMethod_Bank transfer (automatic)  \
# 0                                        0
# ...

# %%
sns.lmplot(data=telco_df_dummies, x='MonthlyCharges', y='TotalCharges', fit_reg=False)

# %%
Mth = sns.kdeplot(telco_df_dummies.MonthlyCharges[(telco_df_dummies["Churn"] == 0) ],
                color="Red", shade = True)
Mth = sns.kdeplot(telco_df_dummies.MonthlyCharges[(telco_df_dummies["Churn"] == 1) ],
                ax =Mth, color="Blue", shade= True)
Mth.legend(["No Churn","Churn"],loc='upper right')
Mth.set_ylabel('Density')
Mth.set_xlabel('Monthly Charges')
Mth.set_title('Monthly charges by churn')
# Out:
# <ipython-input-50-f8c7114217aa>:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   Mth = sns.kdeplot(telco_df_dummies.MonthlyCharges[(telco_df_dummies["Churn"] == 0) ],
# <ipython-input-50-f8c7114217aa>:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   Mth = sns.kdeplot(telco_df_dummies.MonthlyCharges[(telco_df_dummies["Churn"] == 1) ],
# Text(0.5, 1.0, 'Monthly charges by churn')

# %%
Tot = sns.kdeplot(telco_df_dummies.TotalCharges[(telco_df_dummies["Churn"] == 0) ],
                color="Red", shade = True)
Tot = sns.kdeplot(telco_df_dummies.TotalCharges[(telco_df_dummies["Churn"] == 1) ],
                ax =Tot, color="Blue", shade= True)
Tot.legend(["No Churn","Churn"],loc='upper right')
Tot.set_ylabel('Density')
Tot.set_xlabel('Total Charges')
Tot.set_title('Total charges by churn')
# Out:
# <ipython-input-51-ca3e6074781e>:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   Tot = sns.kdeplot(telco_df_dummies.TotalCharges[(telco_df_dummies["Churn"] == 0) ],
# <ipython-input-51-ca3e6074781e>:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   Tot = sns.kdeplot(telco_df_dummies.TotalCharges[(telco_df_dummies["Churn"] == 1) ],
# Text(0.5, 1.0, 'Total charges by churn')

# %%
telco_df_dummies.head(1)
# Out:
#    SeniorCitizen  MonthlyCharges  TotalCharges  Churn  gender_Female  \
# 0              0           29.85         29.85      0              1
#
#    gender_Male  Partner_No  Partner_Yes  Dependents_No  Dependents_Yes  ...  \
# 0            0           0            1              1               0  ...
#
#    PaymentMethod_Bank transfer (automatic)  \
# 0                                        0
#
#    PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 0                                      0                               1
#
#    PaymentMethod_Mailed check  tenure_group_1 - 12  tenure_group_13 - 24  \
# 0                           0                    1                     0
#
#    tenure_group_25 - 36  tenure_group_37 - 48  tenure_group_49 - 60  \
# 0                     0                     0                     0
#
#    tenure_group_61 - 72
# 0                     0
#
# [1 rows x 51 columns]

# %%
plt.figure(figsize=(20,8))
telco_df_dummies.corr()['Churn'].sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10,10))
sns.heatmap(telco_df_dummies.corr(), cmap='crest')
# Out:
# <Axes: >

# %% [markdown]
# Bivariate Analysis with labels

# %%
plot = sns.catplot(x='Partner', kind='count', data=telco_df_Churned, hue='gender',height=8, aspect=1.5)

# Adding labels
plt.title('Partner vs Gender for Churned Customers')
plt.xlabel('Partner')
plt.ylabel('Count')

# Adding values on top of the bars
ax = plot.facet_axis(0, 0)
for p in ax.patches:
    ax.text(p.get_x() + p.get_width() / 2., p.get_height(), f'{int(p.get_height())}', ha='center', va='bottom')

# Show the plot
plt.show()

# %%
plot = sns.catplot(x='Partner', kind='count', data=telco_df_Active, hue='gender', height=8, aspect=1.5)

# Adding labels
plt.title('Partner vs Gender for Active Customers')
plt.xlabel('Partner')
plt.ylabel('Count')

# Adding values on top of the bars
ax = plot.facet_axis(0, 0)
for p in ax.patches:
    ax.text(p.get_x() + p.get_width() / 2., p.get_height(), f'{int(p.get_height())}', ha='center', va='bottom')

# Show the plot
plt.show()

# %%
plot = sns.catplot(x='SeniorCitizen', kind='count', data=telco_df_Churned, hue='gender')

# Adding labels
plt.title('SC vs Gender for Churned Customers')
plt.xlabel('SC')
plt.ylabel('Count')

# Adding values on top of the bars
ax = plot.facet_axis(0, 0)
for p in ax.patches:
    ax.text(p.get_x() + p.get_width() / 2., p.get_height(), f'{int(p.get_height())}', ha='center', va='bottom')

# Show the plot
plt.show()

# %%
plot = sns.catplot(x='SeniorCitizen', kind='count', data=telco_df_Active, hue='gender', height=8, aspect=1.5)

# Adding labels
plt.title('SC vs Gender for Active Customers')
plt.xlabel('SC')
plt.ylabel('Count')

# Adding values on top of the bars
ax = plot.facet_axis(0, 0)
for p in ax.patches:
    ax.text(p.get_x() + p.get_width() / 2., p.get_height(), f'{int(p.get_height())}', ha='center', va='bottom')

# Show the plot
plt.show()

# %%
plot = sns.catplot(x='Dependents', kind='count', data=telco_df_Churned, hue='gender', height=8, aspect=1.5)

# Adding labels
plt.title('Dependents vs Gender for Churned Customers')
plt.xlabel('Dependents')
plt.ylabel('Count')

# Adding values on top of the bars
ax = plot.facet_axis(0, 0)
for p in ax.patches:
    ax.text(p.get_x() + p.get_width() / 2., p.get_height(), f'{int(p.get_height())}', ha='center', va='bottom')

# Show the plot
plt.show()

# %%
plot = sns.catplot(x='Dependents', kind='count', data=telco_df_Active, hue='gender', height=8, aspect=1.5)

# Adding labels
plt.title('Dependents vs Gender for Active Customers')
plt.xlabel('Dependents')
plt.ylabel('Count')

# Adding values on top of the bars
ax = plot.facet_axis(0, 0)
for p in ax.patches:
    ax.text(p.get_x() + p.get_width() / 2., p.get_height(), f'{int(p.get_height())}', ha='center', va='bottom')

# Show the plot
plt.show()

# %%
plot = sns.catplot(x='PhoneService', kind='count', data=telco_df_Churned, hue='gender', height=8, aspect=1.5)

# Adding labels
plt.title('Phone Service vs Gender for Churned Customers')
plt.xlabel('Phone Service')
plt.ylabel('Count')

# Adding values on top of the bars
ax = plot.facet_axis(0, 0)
for p in ax.patches:
    ax.text(p.get_x() + p.get_width() / 2., p.get_height(), f'{int(p.get_height())}', ha='center', va='bottom')

# Show the plot
plt.show()

# %%
plot = sns.catplot(x='PhoneService', kind='count', data=telco_df_Active, hue='gender', height=8, aspect=1.5)

# Adding labels
plt.title('Phone Service vs Gender for Active Customers')
plt.xlabel('Phone Service')
plt.ylabel('Count')

# Adding values on top of the bars
ax = plot.facet_axis(0, 0)
for p in ax.patches:
    ax.text(p.get_x() + p.get_width() / 2., p.get_height(), f'{int(p.get_height())}', ha='center', va='bottom')

# Show the plot
plt.show()

# %%
plot = sns.catplot(x='InternetService', kind='count', data=telco_df_Churned, hue='gender', height=8, aspect=1.5)

# Adding labels
plt.title('InternetService vs Gender for Churned Customers')
plt.xlabel('InternetService')
plt.ylabel('Count')

# Adding spaces between the labels
ax = plot.facet_axis(0, 0)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')  # Rotate and align the labels for better visibility
plt.xticks(rotation=45, ha='right')

# Adding values on top of the bars
for p in ax.patches:
    ax.text(p.get_x() + p.get_width() / 2., p.get_height(), f'{int(p.get_height())}', ha='center', va='bottom')

# Show the plot
plt.show()

# %%
plot = sns.catplot(x='InternetService', kind='count', data=telco_df_Active, hue='gender', height=8, aspect=1.5)

# Adding labels
plt.title('InternetService vs Gender for Active Customers')
plt.xlabel('InternetService')
plt.ylabel('Count')

# Adding spaces between the labels
ax = plot.facet_axis(0, 0)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')  # Rotate and align the labels for better visibility
plt.xticks(rotation=45, ha='right')

# Adding values on top of the bars
for p in ax.patches:
    ax.text(p.get_x() + p.get_width() / 2., p.get_height(), f'{int(p.get_height())}', ha='center', va='bottom')

# Show the plot
plt.show()

# %%
plot = sns.catplot(x='OnlineSecurity', kind='count', data=telco_df_Churned, hue='gender', height=8, aspect=1.5)

# Adding labels
plt.title('OnlineSecurity vs Gender for Churned Customers')
plt.xlabel('OnlineSecurity')
plt.ylabel('Count')

# Adding spaces between the labels
ax = plot.facet_axis(0, 0)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')  # Rotate and align the labels for better visibility
plt.xticks(rotation=45, ha='right')

# Adding values on top of the bars
for p in ax.patches:
    ax.text(p.get_x() + p.get_width() / 2., p.get_height(), f'{int(p.get_height())}', ha='center', va='bottom')

# Show the plot
plt.show()

# %%
plot = sns.catplot(x='OnlineSecurity', kind='count', data=telco_df_Active, hue='gender', height=8, aspect=1.5)

# Adding labels
plt.title('OnlineSecurity vs Gender for Active Customers')
plt.xlabel('OnlineSecurity')
plt.ylabel('Count')

# Adding spaces between the labels
ax = plot.facet_axis(0, 0)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')  # Rotate and align the labels for better visibility
plt.xticks(rotation=45, ha='right')

# Adding values on top of the bars
for p in ax.patches:
    ax.text(p.get_x() + p.get_width() / 2., p.get_height(), f'{int(p.get_height())}', ha='center', va='bottom')

# Show the plot
plt.show()

# %%
plot = sns.catplot(x='OnlineBackup', kind='count', data=telco_df_Churned, hue='gender', height=8, aspect=1.5)

# Adding labels
plt.title('OnlineBackup vs Gender for Churned Customers')
plt.xlabel('OnlineBackup')
plt.ylabel('Count')

# Adding spaces between the labels
ax = plot.facet_axis(0, 0)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')  # Rotate and align the labels for better visibility
plt.xticks(rotation=45, ha='right')

# Adding values on top of the bars
for p in ax.patches:
    ax.text(p.get_x() + p.get_width() / 2., p.get_height(), f'{int(p.get_height())}', ha='center', va='bottom')

# Show the plot
plt.show()

# %%
plot = sns.catplot(x='OnlineBackup', kind='count', data=telco_df_Active, hue='gender', height=8, aspect=1.5)

# Adding labels
plt.title('OnlineBackup vs Gender for Active Customers')
plt.xlabel('OnlineBackup')
plt.ylabel('Count')

# Adding spaces between the labels
ax = plot.facet_axis(0, 0)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')  # Rotate and align the labels for better visibility
plt.xticks(rotation=45, ha='right')

# Adding values on top of the bars
for p in ax.patches:
    ax.text(p.get_x() + p.get_width() / 2., p.get_height(), f'{int(p.get_height())}', ha='center', va='bottom')

# Show the plot
plt.show()

# %%
plot = sns.catplot(x='DeviceProtection', kind='count', data=telco_df_Churned, hue='gender', height=8, aspect=1.5)

# Adding labels
plt.title('DeviceProtection vs Gender for Churned Customers')
plt.xlabel('DeviceProtection')
plt.ylabel('Count')

# Adding spaces between the labels
ax = plot.facet_axis(0, 0)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')  # Rotate and align the labels for better visibility
plt.xticks(rotation=45, ha='right')

# Adding values on top of the bars
for p in ax.patches:
    ax.text(p.get_x() + p.get_width() / 2., p.get_height(), f'{int(p.get_height())}', ha='center', va='bottom')

# Show the plot
plt.show()

# %%
plot = sns.catplot(x='DeviceProtection', kind='count', data=telco_df_Active, hue='gender', height=8, aspect=1.5)

# Adding labels
plt.title('DeviceProtection vs Gender for Active Customers')
plt.xlabel('DeviceProtection')
plt.ylabel('Count')

# Adding spaces between the labels
ax = plot.facet_axis(0, 0)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')  # Rotate and align the labels for better visibility
plt.xticks(rotation=45, ha='right')

# Adding values on top of the bars
for p in ax.patches:
    ax.text(p.get_x() + p.get_width() / 2., p.get_height(), f'{int(p.get_height())}', ha='center', va='bottom')

# Show the plot
plt.show()

# %%
plot = sns.catplot(x='Contract', kind='count', data=telco_df_Churned, hue='gender', height=8, aspect=1.5)

# Adding labels
plt.title('Contract vs Gender for Churned Customers')
plt.xlabel('Contract')
plt.ylabel('Count')

# Adding spaces between the labels
ax = plot.facet_axis(0, 0)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')  # Rotate and align the labels for better visibility
plt.xticks(rotation=45, ha='right')

# Adding values on top of the bars
for p in ax.patches:
    ax.text(p.get_x() + p.get_width() / 2., p.get_height(), f'{int(p.get_height())}', ha='center', va='bottom')

# Show the plot
plt.show()

# %%
plot = sns.catplot(x='Contract', kind='count', data=telco_df_Active, hue='gender', height=8, aspect=1.5)

# Adding labels
plt.title('Contract vs Gender for Active Customers')
plt.xlabel('Contract')
plt.ylabel('Count')

# Adding spaces between the labels
ax = plot.facet_axis(0, 0)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')  # Rotate and align the labels for better visibility
plt.xticks(rotation=45, ha='right')

# Adding values on top of the bars
for p in ax.patches:
    ax.text(p.get_x() + p.get_width() / 2., p.get_height(), f'{int(p.get_height())}', ha='center', va='bottom')

# Show the plot
plt.show()

# %%
plot = sns.catplot(x='PaymentMethod', kind='count', data=telco_df_Churned, hue='gender', height=8, aspect=1.5)

# Adding labels
plt.title('PaymentMethod vs Gender for Churned Customers')
plt.xlabel('PaymentMethod')
plt.ylabel('Count')

# Adding spaces between the labels
ax = plot.facet_axis(0, 0)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')  # Rotate and align the labels for better visibility
plt.xticks(rotation=45, ha='right')

# Adding values on top of the bars
for p in ax.patches:
    ax.text(p.get_x() + p.get_width() / 2., p.get_height(), f'{int(p.get_height())}', ha='center', va='bottom')

# Show the plot
plt.show()

# %%
plot = sns.catplot(x='PaymentMethod', kind='count', data=telco_df_Active, hue='gender', height=8, aspect=1.5)
# Adding labels
plt.title('PaymentMethod vs Gender for Active Customers')
plt.xlabel('PaymentMethod')
plt.ylabel('Count')

# Adding spaces between the labels
ax = plot.facet_axis(0, 0)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')  # Rotate and align the labels for better visibility
plt.xticks(rotation=45, ha='right')

# Adding values on top of the bars
for p in ax.patches:
    ax.text(p.get_x() + p.get_width() / 2., p.get_height(), f'{int(p.get_height())}', ha='center', va='bottom')

# Show the plot
plt.show()

# %%
plot = sns.catplot(x='tenure_group', kind='count', data=telco_df_Churned, hue='gender', height=8, aspect=1.5)
# Adding labels
plt.title('tenure group vs Gender for Churned Customers')
plt.xlabel('tenure group')
plt.ylabel('Count')

# Adding spaces between the labels
ax = plot.facet_axis(0, 0)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')  # Rotate and align the labels for better visibility
plt.xticks(rotation=45, ha='right')

# Adding values on top of the bars
for p in ax.patches:
    ax.text(p.get_x() + p.get_width() / 2., p.get_height(), f'{int(p.get_height())}', ha='center', va='bottom')

# Show the plot
plt.show()

# %%
plot = sns.catplot(x='tenure_group', kind='count', data=telco_df_Active, hue='gender', height=8, aspect=1.5)
# Adding labels
plt.title('tenure group vs Gender for Active Customers')
plt.xlabel('tenure group')
plt.ylabel('Count')

# Adding spaces between the labels
ax = plot.facet_axis(0, 0)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')  # Rotate and align the labels for better visibility
plt.xticks(rotation=45, ha='right')

# Adding values on top of the bars
for p in ax.patches:
    ax.text(p.get_x() + p.get_width() / 2., p.get_height(), f'{int(p.get_height())}', ha='center', va='bottom')

# Show the plot
plt.show()

# %% [markdown]
# Insights from Bivariate Analysis
#
# 1. Female users actively using optic internet services tend to have a higher churn rate.
# 2. Female customers who do not use online security features are more likely to be associated with a high churn rate.
# 3. Females without any partner are more likely to churn.
# 4. Males using Credit cards are more likely to churn.
# 5. Females who do not utilize device protection are more likely to experience a higher churn rate.
# 6. Females with tenure in the 1-12 month range are characterized by a higher churn rate
# 7. Male customers who use electronic cheque services are more likely to exhibit a high churn rate.
